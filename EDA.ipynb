# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
iris=pd.read_csv("C:\\Users\\nqnqa\\Downloads\\IRIS.csv")

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.scatterplot(data=iris , x="sepal_length" , y="sepal_width" , hue = "species"  )
plt.grid()

# %%
# !pip install plotly.express
# Out:
# ...
#    ---------------------------------------- 0.0/233.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/233.9 kB ? eta -:--:--
#    ---------- ---------------------------- 61.4/233.9 kB 812.7 kB/s eta 0:00:01
#    --------------------------------- ------ 194.6/233.9 kB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 225.3/233.9 kB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 225.3/233.9 kB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 225.3/233.9 kB 2.0 MB/s eta 0:00:01
#    -------------------------------------- 233.9/233.9 kB 753.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#     --------------------------------------- 0.1/9.8 MB 2.8 MB/s eta 0:00:04
#    - -------------------------------------- 0.4/9.8 MB 4.9 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/9.8 MB 4.8 MB/s eta 0:00:02
# ...

# %%
import plotly.express as px
df=px.data.iris()
fig=px.scatter_3d(df,x='sepal_length', y='sepal_width', z='petal_length', color="species")
fig.show()

# %%
sns.scatterplot(data=iris , x="petal_length" , y="petal_width" , hue = "species"  )
plt.grid()

# %%
iris_1=sns.pairplot(data=iris,hue="species")
plt.show()

# %%
iris["sepal_length"].hist()
plt.savefig("pairplots.svg")

# %%
sns.histplot(data=iris,x="petal_length" , hue="species", bins=120)
plt.grid()

# %%
iris_setosa=iris.loc[iris["species"]=="Iris-setosa"]
iris_versicolor=iris.loc[iris["species"]=="Iris-versicolor"]
iris_virginica=iris.loc[iris["species"]=="Iris-virginica"]
a=plt.plot(iris_setosa["petal_length"],np.zeros_like(iris_setosa["petal_length"]))
plt.plot(iris_versicolor["petal_length"],np.zeros_like(iris_setosa["petal_length"]))
plt.plot(iris_virginica["petal_length"],np.zeros_like(iris_setosa["petal_length"]))
a=plt.grid()

# %%
iris1=pd.read_csv("C:\\Users\\nqnqa\\Downloads\\IRIS.csv")
sns.FacetGrid(data=iris1, hue="species")\
   .map(sns.distplot,"petal_length")\
   .add_legend()
plt.show()
# Out:
# C:\Users\nqnqa\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\nqnqa\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# # UNIVARIATE

# %%
#UNIVARIATE
iris1=iris.groupby("species")

# %%
for species  ,species_iris in iris1:
    print (species)
    print(species_iris)
# Out:
# Iris-setosa
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
Iris_setosa=iris1.get_group("Iris-setosa")
Iris_versicolor=iris1.get_group("Iris-versicolor")
Iris_virginica=iris1.get_group("Iris-virginica")

# %%
#Unvariate
sns.histplot(data=iris,x="sepal_length", hue="species" , bins=100)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data=iris,x="petal_length", hue="species" , bins=100)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(data=iris,x="sepal_width", hue="species" , bins=100)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data=iris,x="petal_width", hue="species" , bins=100)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.FacetGrid(data=iris,hue="species" )\
   .map(sns.distplot,"petal_width")\
   .add_legend()
plt.show()

sns.FacetGrid(data=iris,hue="species" )\
   .map(sns.distplot,"petal_length")\
   .add_legend()
plt.show()
# Out:
# C:\Users\nqnqa\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\nqnqa\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
#SO AFTER LOOKING EACH POSSIBILITY OUR FIRST PREFERENCE SHOULD BE PETAL_LENGTH > PETAL_WIDTH >SEPAL_LENGTH>SEPAL_WIDTH

# %% [markdown]
# CDF

# %%
counts ,bin_edges=np.histogram(Iris_setosa["petal_length"] )
pdf=counts/(sum(counts))


#cdf
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
counts ,bin_edges=np.histogram(Iris_versicolor["petal_length"] )
pdf=counts/(sum(counts))


#cdf
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
counts ,bin_edges=np.histogram(Iris_virginica["petal_length"] )
pdf=counts/(sum(counts))


#cdf
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.grid()
